# %% [markdown]
# `Machine Learning Clasificación y Regresión | **API 1** | **Alumna:** Analía Elizabeth Gomory | Salta - 4400 - Argentina | 2025`
#
# **by Analía Elizabeth Gomory**
#
# * ae.gomory@gmail.com
#
# * http://www.linkedin.com/in/elizabeth-gomory-9240b1217
#
# * https://ae-gomory.itch.io
#
# * https://github.com/ElizabethGomory
#
# * https://www.credly.com/users/analia-gomory
#
# * https://orcid.org/0009-0003-0498-7658

# %% [markdown]
# **1.** Importar librerías y Archivos .csv

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv ("AmesHousing.csv")
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %% [markdown]
# **2.** Normalización de Base de Datos

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
df_nulos=df.isnull().sum().sum()
df_nulos
# Out:
# 15749

# %%
df_nulos=df.isnull().sum()
df_nulos
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %% [markdown]
# **3.** Entrenamiento y Validación de los Datos

# %%
train_df, test_df = train_test_split(df,test_size=0.2, random_state=0)
df_num = df.select_dtypes(include=['float64','int64'])

# Matriz de Morrelación
matriz_correlacion = df_num.corr()
corr_sup = matriz_correlacion[matriz_correlacion.abs()>0.60]
corr_sup
# Out:
#                     Order  PID  MS SubClass  Lot Frontage  Lot Area  \
# Order            1.000000  NaN          NaN           NaN       NaN
# PID                   NaN  1.0          NaN           NaN       NaN
# MS SubClass           NaN  NaN          1.0           NaN       NaN
# Lot Frontage          NaN  NaN          NaN           1.0       NaN
# Lot Area              NaN  NaN          NaN           NaN       1.0
# Overall Qual          NaN  NaN          NaN           NaN       NaN
# Overall Cond          NaN  NaN          NaN           NaN       NaN
# Year Built            NaN  NaN          NaN           NaN       NaN
# Year Remod/Add        NaN  NaN          NaN           NaN       NaN
# Mas Vnr Area          NaN  NaN          NaN           NaN       NaN
# BsmtFin SF 1          NaN  NaN          NaN           NaN       NaN
# BsmtFin SF 2          NaN  NaN          NaN           NaN       NaN
# Bsmt Unf SF           NaN  NaN          NaN           NaN       NaN
# ...

# %% [markdown]
# *#* Extra

# %%
corr_filtrar = corr_sup.where(corr_sup<1)
corr_hard = corr_filtrar.unstack().dropna().sort_values(ascending=False)
print ("N° Total de Variables con Correlaciones Superiores al 60%: ", len(corr_filtrar.columns))
print ("Correlaciones Fuertes: ")
print (corr_hard.head())
# Out:
# N° Total de Variables con Correlaciones Superiores al 60%:  39
# Correlaciones Fuertes:
# Garage Cars    Garage Area      0.889676
# Garage Area    Garage Cars      0.889676
# Garage Yr Blt  Year Built       0.834849
# Year Built     Garage Yr Blt    0.834849
# Gr Liv Area    TotRms AbvGrd    0.807772
# dtype: float64
